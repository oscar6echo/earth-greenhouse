# %%
# %load_ext autoreload
# %autoreload 2

# %%
import simul_co2_absorption as m

# %%
z_max = 80_000
z_delta = 10
lambda_min = 0.1e-6
lambda_max = 100e-6
lambda_delta = 0.01e-6


c = m.Simul(
    z_max=z_max,
    z_delta=z_delta,
    lambda_min=lambda_min,
    lambda_max=lambda_max,
    lambda_delta=lambda_delta,
)
# Out:
# lammbda min              = 0.10 x 10⁻⁶
# lammbda max              = 100  x 10⁻⁶
# lammbda delta            = 0    x 10⁻⁶
#
# alt min                  = 0
# alt max                  = 80,000
# alt delta                = 10

# %%
model = "uniform"

c.calc_scenarii(temperature_model=model)
# Out:
# --- earth flux
# Total earth surface flux in wavelength range: 389.11 W m⁻²
#
# --- scenario 1
# temperature model        = uniform
# co2 fraction             = 280 x 10⁻⁶
# nb layers = 8,000
# 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900
# Total atmosphere flux in wavelength range: 389.11 W m⁻²
# runtime = 4.45 s
#
# --- scenario 2
# temperature model        = uniform
# co2 fraction             = 560 x 10⁻⁶
# nb layers = 8,000
# 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900
# Total atmosphere flux in wavelength range: 389.11 W m⁻²
# runtime = 4.59 s

# %%
c.plot()

# %%
model = "simple"
# model = "US1976"

c.calc_scenarii(temperature_model=model)
# Out:
# --- earth flux
# Total earth surface flux in wavelength range: 389.11 W m⁻²
#
# --- scenario 1
# temperature model        = simple
# co2 fraction             = 280 x 10⁻⁶
# nb layers = 8,000
# 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900
# Total atmosphere flux in wavelength range: 335.91 W m⁻²
# runtime = 5.15 s
#
# --- scenario 2
# temperature model        = simple
# co2 fraction             = 560 x 10⁻⁶
# nb layers = 8,000
# 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900
# Total atmosphere flux in wavelength range: 331.08 W m⁻²
# runtime = 4.84 s

# %%
c.plot()

# %%
model = "US1976"

c.calc_scenarii(temperature_model=model)
# Out:
# --- earth flux
# Total earth surface flux in wavelength range: 389.11 W m⁻²
#
# --- scenario 1
# temperature model        = US1976
# co2 fraction             = 280 x 10⁻⁶
# nb layers = 8,000
# 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700
# /home/olivier/GDrive/dev/science-etonnante/simul_co2_absorption/model.py:39: RuntimeWarning: overflow encountered in exp
#   term2 = np.exp((h * c) / (lambda_wavelength * kB * T)) - 1
# 7800 7900
# Total atmosphere flux in wavelength range: 348.13 W m⁻²
# runtime = 5.08 s
#
# --- scenario 2
# temperature model        = US1976
# co2 fraction             = 560 x 10⁻⁶
# nb layers = 8,000
# 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900
# Total atmosphere flux in wavelength range: 343.57 W m⁻²
# runtime = 5.07 s

# %%
c.plot()
